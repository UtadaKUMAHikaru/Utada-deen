# %%
import gpt_2_simple as gpt2
import tensorflow as tf
# Out:
# 2022-11-05 13:48:38.758420: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd
import re

# %%
seed = "The person was walking to the store when"

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 416Mit/s]
# Fetching encoder.json: 1.05Mit [00:01, 687kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 503Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [04:14, 1.96Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 453Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:01, 979kit/s]
# Fetching vocab.bpe: 1.05Mit [00:01, 941kit/s]

# %%
# %run 3.Emotion\ Profiler.ipynb
# Out:
# /Users/chendeen/miniconda3/envs/dynamic_story_generation/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# <table style='display: inline' border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>idf_weights</th>
#     </tr>
#     <tr>
#       <th>anger</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>angry</th>
#       <td>2.764360</td>
#     </tr>
#     <tr>
#       <th>friend</th>
#       <td>2.928471</td>
#     </tr>
#     <tr>
#       <th>one</th>
#       <td>3.340325</td>
#     </tr>
#     <tr>
#       <th>got</th>
#       <td>3.615268</td>
#     </tr>
#     <tr>
#       <th>time</th>
#       <td>3.640911</td>
#     </tr>
#     <tr>
#       <th>told</th>
# ...

# %%
sess = gpt2.start_tf_sess()
# for emotion in isear_df.emotion.unique().tolist():
# for emotion in ["sadness"]:
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.finetune(
    sess,
    "../corpora/harry_potter/full_text.txt",
    model_name="124M",
    steps=10,
    # steps=1000,
    restore_from="fresh",
    run_name="full_text_small_run1",
    print_every=10,
    sample_every=200,
    save_every=500
)
# Out:
# 2022-11-05 13:54:21.395608: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-05 13:54:31.870194: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# dataset has 92342 tokens
# Training...
# [10 | 406.74] loss=3.02 avg=3.02
# Saving checkpoint/full_text_small_run1/model-10

# %%
# 需要有一个文件夹叫"sad"
emo = "sad"
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name=emo)

gpt2.generate(
    sess,
    length=50,
    temperature=0.7,
    prefix="I think today will be",
    nsamples=1,
    batch_size=1,
    run_name=f"{emo}_run1"
)
# Out:
# Loading checkpoint None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/b7/3f2gz_w91pq_k0p2grs6fm7w0000gn/T/ipykernel_62666/3011590870.py in <module>
#       2 gpt2.reset_session(sess)
#       3 sess = gpt2.start_tf_sess()
# ----> 4 gpt2.load_gpt2(sess, run_name=emo)
#       5
#       6 gpt2.generate(
#
# ~/miniconda3/envs/dynamic_story_generation/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in load_gpt2(sess, checkpoint, run_name, checkpoint_dir, model_name, model_dir, multi_gpu, reuse)
#     406     else:
#     407         print('Loading checkpoint', ckpt)
# --> 408     saver.restore(sess, ckpt)
#     409
#     410
#
# ~/miniconda3/envs/dynamic_story_generation/lib/python3.7/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1401       return
#    1402     if save_path is None:
# ...

# %%
sess = gpt2.start_tf_sess()

# %%
lyrics = pd.read_csv("../corpora/Rap_songs.csv").lyrics.tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/b7/3f2gz_w91pq_k0p2grs6fm7w0000gn/T/ipykernel_62666/3658153973.py in <module>
# ----> 1 lyrics = pd.read_csv("../corpora/Rap_songs.csv").lyrics.tolist()
#
# ~/miniconda3/envs/dynamic_story_generation/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
with open("../corpora/rap_aggregate.txt", "w") as rap_writer:
    for song in lyrics:
        rap_writer.write(f"{song.strip()}\n")

# %%
character = "hagrid"

# gpt2.reset_session(sess)
# f"../corpora/harry_potter/characters/{character}.txt",
sess = gpt2.start_tf_sess()
gpt2.finetune(
    sess,
    f"../corpora/harry_potter/full_text.txt",
    model_name="155M",
    steps=10,
    # steps=1000,
    restore_from="fresh",
    run_name=f"full_model_small",
    print_every=10,
    sample_every=200,
    save_every=500
)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-8a922e6b36d0> in <module>
#      13     print_every=10,
#      14     sample_every=200,
# ---> 15     save_every=500
#      16 )
#
# ~/anaconda3/lib/python3.7/site-packages/gpt_2_simple/gpt_2.py in finetune(sess, dataset, steps, model_name, model_dir, combine, batch_size, learning_rate, accumulate_gradients, restore_from, run_name, checkpoint_dir, sample_every, sample_length, sample_num, multi_gpu, save_every, print_every, max_checkpoints, use_memory_saving_gradients, only_train_transformer_layers, optimizer, overwrite)
#     176             raise(fnf_error)
#     177
# --> 178     enc = encoder.get_encoder(checkpoint_path)
#     179     hparams = model.default_hparams()
#     180     with open(os.path.join(checkpoint_path, 'hparams.json')) as f:
#
# ...

# %%
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name=f"rapper_run1")
gpt2.generate(
    sess,
    length=300,
    temperature=0.8,
    prefix="[Verse 1]\nWash your hands, dont get sick\nStay on your lands, now be quick\n",
    nsamples=3,
    batch_size=1,
    run_name="rapper_run1",
    model_name="355M"
)
# Out:
# Loading checkpoint checkpoint/rapper_run1/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/rapper_run1/model-1000
# [Verse 1]
# Wash your hands, dont get sick
# Stay on your lands, now be quick
# We get freaky in the alley, I'm just passing the baton
# Let the hoes pounce, now you're in for a treat
# Tryna scoop up some pumpernickel sis
# Little fidget spin for your viewing pleasure
#
# [Verse 2]
# Excusez-moi, est-ce que vous savez où est un bon restaurant par ici?
#
# [Chorus]
#
# [Verse 1]
# Bruh, I'm not the only one
# That's why I'm always on the move
# My slaves back home, they won't be deprived
# They'll be free, like a kangaroo
# I can keep you company, oh?
#
# [Verse 2]
# I'm not the one you really wanna try
# I'd advise that you run and hide
# When my Nimrod side's rage starts to rise
# If you wanna feel defeat I'll oblige
# Step up to me to meet your demise
# Thanos, now you're the source of my agitation
# Better hope I go under sedation
# ...

# %%
for emotion, row in character_profiles["harry"].iterrows():
    print(emotion, row.percent)
# Out:
# disgust 0.1648003693706231
# anger 0.15647319632351026
# fear 0.15555055201494097
# guilt 0.14739040651343888
# shame 0.14720370046697356
# joy 0.12097886589742116
# sadness 0.10760290941309218
